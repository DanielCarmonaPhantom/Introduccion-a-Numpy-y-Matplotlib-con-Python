# %% [markdown]
# # Sesión 7 Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Este sirve para mostar de manera explícita que se va a hacer una figura, no es necesario ponerlo
fig = plt.figure()  
fig.set_size_inches(5,5)
plt.plot()
fig.show()

# %%
plt.figure(figsize=(5,5))
plt.plot()
# Out:
# []

# %%
x = 1
y = 1

fig = plt.figure(figsize=(5,5))

fig.set_size_inches(6,6)

plt.plot(x,y);

# %% [markdown]
# Solo se pueden hacer líneas

# %%
x = 1
y = 1

fig = plt.figure(figsize=(5,5))

fig.set_size_inches(6,6)

plt.plot(x,y, marker='*');

# %%
x = [1,2]
y = [1,1]

fig = plt.figure(figsize=(5,5))

fig.set_size_inches(6,6)

plt.plot(x,y);

# %%
x = [1,2,3,4,5,6,7,8,9]
y = [1,4,9,16,25,36,48,64,81]

fig = plt.figure(figsize=(5,5))

fig.set_size_inches(6,6)

plt.plot(x,y);

# %%
fig = plt.figure(figsize=(5,5))

fig.set_size_inches(6,6)

plt.plot(np.arange(11), np.arange(11)**2);

# %%
fig = plt.figure(figsize=(5,5))

fig.set_size_inches(6,6)

plt.grid()
plt.plot(np.arange(11), np.arange(11)**2);

# %%
x = 1
y = 1

fig = plt.figure(figsize=(5,5))

fig.set_size_inches(6,6)

plt.plot(x,y, marker='*', markersize = 10, color ='red');

# %%
x = np.linspace(0,60,120)
y = np.sin(x)

fig = plt.figure(figsize=(5,5))

fig.set_size_inches(6,6)

plt.plot(x,y);

# %%
u = np.linspace(-100,100,300)

x = 10*np.sin(u)
y = 10*np.cos(u)

fig = plt.figure(figsize=(5,5))

fig.set_size_inches(6,6)

plt.plot(x,y);

# %%
fig = plt.figure(figsize=(5,5))

x = np.linspace(-10,10,1000)
y = 1/(1+x**2)

x1 = x
y1 = np.abs(np.sin(x))*3

y1[500:] = x1[500:]**2

plt.ylim(-10,10)
plt.xlim(-10,10)

plt.grid()
fig.set_size_inches(6,6)

plt.plot(x,y, color ='red', label='luminosidad');
plt.plot(x1,y1, color ='red', label='Altura', marker="*", linestyle='--', linewidth=1.5);
